# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = sum(np.square(y-yp)) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error( y, y_hat)
MAE = mean_absolute_error( y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 295.898
# The Mean absolute error is 13.868

# %% [markdown]
# HW1
#
# https://www.kaggle.com/ronitf/heart-disease-uci
#
# 1. 你選的這組資料為何重要 : 提早判斷心血管疾病發生的可能性
#
# 2. 資料從何而來 : 公開發表的醫療實驗數據
#
# 3. 蒐集而來的資料型態為何 : 結構化，CSV 格式，資料欄位有明確定義 (年紀、性別、血壓…)
#
# 4. 這組資料想解決的問題如何評估 : 發病與否 (Target = 0 代表無)

# %% [markdown]
# HW2
#
# 1. 核心問題為何 : 適當配置車隊人力與等待地點來提昇車隊整體業績
#
# 2. 資料從何而來 : 車隊 GPS 定位系統、叫車 APP
#
# 3. 蒐集而來的資料型態為何 : 結構化，CSV 格式，包括載客的時間、地點、車資等
#
# 4. 你要回答的問題，其如何評估 : 將叫車時段與區域加權評分來最大化業績
